# %%
import cvxpy as cp
import numpy as np
import warnings
import sys
from IPython.core.interactiveshell import InteractiveShell
from sklearn.preprocessing import StandardScaler
import torch
import torch.optim as optim
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

from torch.autograd import Function

from itertools import product
import numpy as np
import torch.nn as nn
from torch.utils.data import DataLoader
import copy
import json
from datetime import datetime

from pyepo.model.opt import optModel


sys.path.insert(0, 'E:\\User\\Stevens\\Code\\The Paper\\algorithm')

from myutil import *
from features import get_all_features
# Suppress warnings
warnings.filterwarnings("ignore")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

df = pd.read_csv('data/data.csv')

df = df.sample(n=500, random_state=42)
df.shape

columns_to_keep = [
    'risk_score_t', 'program_enrolled_t', 'cost_t', 'cost_avoidable_t', 'race', 'dem_female', 'gagne_sum_tm1', 'gagne_sum_t', 
    'risk_score_percentile', 'screening_eligible', 'avoidable_cost_mapped', 'propensity_score', 'g_binary', 
    'g_continuous', 'utility_binary', 'utility_continuous'
]
# for race 0 is white, 1 is black
df_stat = df[columns_to_keep]
df_feature = df[[col for col in df.columns if col not in columns_to_keep]]

# Replace all values less than 0.1 with 0.1
#df['risk_score_t'] = df['risk_score_t'].apply(lambda x: 0.1 if x < 0.1 else x)
df['g_continuous'] = df['g_continuous'].apply(lambda x: 0.1 if x < 0.1 else x)
# Out:
# Auto-Sklearn cannot be imported.
# cuda

# %%
alpha, Q = 0.5, 100

# %%
# Define input variables for DFL
feats = df_feature[get_all_features(df_feature)].values
risk = df_stat['risk_score_t'].values.clip(0.001)
gainF = df_stat['g_continuous'].values.clip(0.1)
decision = df_stat['propensity_score'].values
cost = np.ones(risk.shape)
race = df_stat['race'].values

# Transform the features
scaler = StandardScaler()
feats = scaler.fit_transform(feats)

# Train-test split
feats_train, feats_test, gainF_train, gainF_test, risk_train, risk_test, cost_train, cost_test, race_train, race_test = train_test_split(
    feats, gainF, risk, cost, race, test_size=0.5, random_state=42
)

print(f"Train size: {feats_train.shape}")
print(f"Test size: {feats_test.shape}")
# Out:
# Train size: (250, 147)
# Test size: (250, 147)

# %%
class AlphaFairModel(optModel):
    def __init__(self, alpha=alpha, N=None, Q=Q):
        self.alpha = alpha
        self.N = N
        self.Q = Q
        self.cost = None
        self.gainF = None  # Separate gain factor
        self.risk = None   # Separate risk
        self._problem = None
        self.d = None
        self.t = None
        super().__init__()
        
    def _getModel(self):
        if self.N is None:
            raise ValueError("Model size N must be set before initialization")
            
        self.d = cp.Variable(self.N, nonneg=True)
        model_vars = {"d": self.d}
        
        if self.alpha == 'inf':
            self.t = cp.Variable()
            model_vars["t"] = self.t
            
        return None, model_vars
    
    def setObj(self, risk, gainF, cost):
        if len(risk) != self.N or len(gainF) != self.N:
            raise ValueError(f"Risk and gainF lengths must match N={self.N}")
            
        if isinstance(risk, np.ndarray):
            risk = risk.flatten()
        if isinstance(gainF, np.ndarray):
            gainF = gainF.flatten()
            
        self.risk = risk
        self.gainF = gainF
            
        # Calculate utilities with separate risk and gainF
        utils = cp.multiply(cp.multiply(self.gainF, self.risk), self.d)
        
        constraints = [
            self.d >= 0,
            cp.sum(cp.multiply(cost, self.d)) <= self.Q
        ]
        
        if self.alpha == 0:
            objective = cp.Maximize(cp.sum(utils))
        elif self.alpha == 1:
            objective = cp.Maximize(cp.sum(cp.log(utils)))
        elif self.alpha == 'inf':
            objective = cp.Maximize(self.t)
            constraints.append(utils >= self.t)
        else:
            objective = cp.Maximize(cp.sum(cp.power(utils, 1-self.alpha))/(1-self.alpha))
            
        self._problem = cp.Problem(objective, constraints)
    
    def solve(self):
        if self._problem is None:
            raise ValueError("Must call setObj before solving")
            
        try:
            self._problem.solve(solver=cp.MOSEK, verbose=False, 
                              warm_start=True, 
                              mosek_params={'MSK_IPAR_LOG': 1})
        except Exception as e:
            print(f"Optimization failed: {str(e)}")
            return np.zeros(self.N), 0.0
            
        if self._problem.status not in ["optimal", "optimal_inaccurate"]:
            print(f"Warning: Problem status is {self._problem.status}")
            return np.zeros(self.N), 0.0
            
        optimal_decision = self.d.value
        
        # Calculate optimal value using separate risk and gainF
        utils = optimal_decision * self.risk * self.gainF
        if self.alpha == 1:
            optimal_value = np.sum(np.log(utils))
        elif self.alpha == 0:
            optimal_value = np.sum(utils)
        elif self.alpha == 'inf':
            optimal_value = np.min(utils)
        else:
            optimal_value = np.sum(utils**(1-self.alpha))/(1-self.alpha)
            
        return optimal_decision, optimal_value
    
def compute_d_star_closed_form(g, r, c, alpha=alpha, Q=Q):

    if not isinstance(c, np.ndarray) or not isinstance(r, np.ndarray) or not isinstance(g, np.ndarray):
        raise TypeError("c, r, and g must be numpy arrays.")
    if c.shape != r.shape or c.shape != g.shape:
        raise ValueError("c, r, and g must have the same shape.")
    if np.any(c <= 0):
        raise ValueError("All cost values must be positive.")
    if np.any(r <= 0):
        raise ValueError("All risk values must be positive.")
    if np.any(g <= 0):
        raise ValueError("All gain factors must be positive.")
    
    n = len(c)
    utility = r * g
    
    if alpha == 0:
        ratios = utility / c
        sorted_indices = np.argsort(-ratios)  # Descending order
        d_star_closed = np.zeros(n)
        d_star_closed[sorted_indices[0]] = Q / c[sorted_indices[0]]
        
    elif alpha == 1:
        d_star_closed = Q / (n * c)
    
    elif alpha == 'inf':
        d_star_closed = (Q * c) / (utility * np.sum(c * c / utility))
        
    else:
        if alpha <= 0:
            raise ValueError("Alpha must be positive for general case.")
        #
        # d_i* = (c_i^(-1/alpha) * (r_i*g_i)^(1/alpha - 1) * Q) / sum_j(c_j^(-1/alpha) * (r_j*g_j)^(1/alpha - 1))
        
        numerator = np.power(c, -1/alpha) * np.power(utility, 1/alpha - 1)
        denominator = np.sum(numerator)
        
        if denominator == 0:
            raise ValueError("Denominator is zero in closed-form solution.")
            
        d_star_closed = (numerator / denominator) * Q
    
    # if not np.isclose(np.sum(c * d_star_closed), Q, rtol=1e-5):
    #     raise ValueError("Solution does not satisfy budget constraint.")
        
    return d_star_closed

def compute_gradient_closed_form(g, r, c, alpha, Q):
    """
    Compute the analytical gradient of the optimal solution with respect to r.

    This function computes the gradient matrix where each element (i, k) is the partial derivative
    of d_i* with respect to r_k.

    Parameters:
    - g (np.ndarray): Gain factors (g_i), shape (n,)
    - r (np.ndarray): Risk values (r_i), shape (n,)
    - c (np.ndarray): Cost values (c_i), shape (n,)
    - alpha (float or str): Fairness parameter. Can be 0, 1, 'inf', or a positive real number.
    - Q (float): Total budget.

    Returns:
    - gradient (np.ndarray): Gradient matrix of shape (n, n)
    """
    if alpha == 0:
        # Utilitarian case: Gradient is undefined or zero
        # Since allocation is discrete, gradients are effectively zero
        return np.zeros((len(c), len(c)))

    elif alpha == 1:
        # Nash welfare case: Gradient is zero
        return np.zeros((len(c), len(c)))

    elif alpha == 'inf':
        # Maximin case
        n = len(c)
        utility = r * g  # Shape: (n,)
        S = np.sum(c**2 / utility)  # Scalar

        # Compute d_star
        d_star = compute_d_star_closed_form(g,r,c, alpha='inf', Q=Q)  # Shape: (n,)

        # Initialize gradient matrix
        gradient = np.zeros((n, n))

        for i in range(n):
            for k in range(n):
                if i == k:
                    # ∂d_i*/∂r_i = -d_i*/r_i - (d_i* * c_i) / (r_i * g_i * S)
                    gradient[i, k] = -d_star[i] / r[i] - (d_star[i] * c[i]) / (r[i] * g[i] * S)
                else:
                    # ∂d_i*/∂r_k = (d_i* * c_k^2) / (c_i * r_k^2 * g_k * S)
                    gradient[i, k] = (d_star[i] * c[k]**2) / (c[i] * r[k]**2 * g[k] * S)
        return gradient

    else:
        # General alpha case
        if not isinstance(alpha, (int, float)):
            raise TypeError("Alpha must be a positive real number, 0, 1, or 'inf'.")
        if alpha <= 0:
            raise ValueError("Alpha must be positive for gradient computation.")

        # Compute the optimal decision variables
        d_star = compute_d_star_closed_form(g, r, c, alpha, Q)  # Shape: (n,)

        # Compute the term (1/alpha - 1) * g / r
        term = (1.0 / alpha - 1.0) * g / r  # Shape: (n,)

        # Compute the outer product for off-diagonal elements
        # Each element (i, k) = -d_star[i] * d_star[k] * term[k] / Q
        gradient = -np.outer(d_star, d_star * term) / Q  # Shape: (n, n)

        # Compute the diagonal elements
        # Each diagonal element (i, i) = d_star[i] * term[i] * (1 - d_star[i]/Q)
        diag_elements = d_star * term * (1 - d_star / Q)  # Shape: (n,)

        # Set the diagonal elements
        np.fill_diagonal(gradient, diag_elements)

        return gradient

# %%
def AlphaFairness(util,alpha):
    util = util.detach().cpu().numpy() if isinstance(util, torch.Tensor) else util

    if alpha == 1:
        return np.sum(np.log(util))
    elif alpha == 0:
        return np.sum(util)
    elif alpha == 'inf':
        return np.min(util)
    else:
        return np.sum(util**(1-alpha)/(1-alpha))


def solve_optimization(gainF, risk, cost, alpha, Q):
    # Flatten input arrays

    # if any of the inputs are tensor, convert to numpy array
    gainF = gainF.detach().cpu().numpy() if isinstance(gainF, torch.Tensor) else gainF
    risk = risk.detach().cpu().numpy() if isinstance(risk, torch.Tensor) else risk
    cost = cost.detach().cpu().numpy() if isinstance(cost, torch.Tensor) else cost


    risk = risk.clip(min=0.001)
    gainF, risk, cost = gainF.flatten(), risk.flatten(), cost.flatten()
    d = cp.Variable(risk.shape, nonneg=True)

    # raise error if dimensions do not match
    if gainF.shape != risk.shape or risk.shape != cost.shape:
        raise ValueError("Dimensions of gainF, risk, and cost do not match")
    
    utils = cp.multiply(cp.multiply(gainF, risk), d)
    
    if alpha == 'inf':
        # Maximin formulation
        t = cp.Variable()  # auxiliary variable for minimum utility
        objective = cp.Maximize(t)
        constraints = [
            d >= 0,
            # d <= 1,
            cp.sum(cost * d) <= Q,
            utils >= t  # t is the minimum utility
        ]
    elif alpha == 1:
        # Nash welfare (alpha = 1)
        objective = cp.Maximize(cp.sum(cp.log(utils)))
        constraints = [
            d >= 0,
            # d <= 1,
            cp.sum(cost * d) <= Q
        ]
    elif alpha == 0:
        # Utilitarian welfare (alpha = 0)
        objective = cp.Maximize(cp.sum(utils))
        constraints = [
            d >= 0,
            # d <= 1,
            cp.sum(cost * d) <= Q
        ]
    else:
        # General alpha-fairness
        objective = cp.Maximize(cp.sum(cp.power(utils, 1 - alpha)) / (1 - alpha) if alpha != 0 else cp.sum(utils))
        constraints = [
            d >= 0,
            # d <= 1,
            cp.sum(cost * d) <= Q
        ]
    
    # Solve the problem
    problem = cp.Problem(objective, constraints)
    problem.solve(solver=cp.MOSEK, verbose=False, warm_start=True, mosek_params={'MSK_IPAR_LOG': 1})
    
    if problem.status not in ["optimal", "optimal_inaccurate"]:
        raise ValueError(f"Optimization failed with status {problem.status}")

    
    optimal_decision = d.value
    optimal_value = AlphaFairness(optimal_decision * gainF * risk, alpha)
    
    return optimal_decision, optimal_value

# %% [markdown]
# ## Define the OptModel

# %%
class optDataset(Dataset):
    def __init__(self, optmodel, feats, risk, gainF, cost):
        self.feats = torch.from_numpy(feats).float()
        self.risk = torch.from_numpy(risk).float()
        self.gainF = torch.from_numpy(gainF).float()
        self.cost = torch.from_numpy(cost).float()

        # Solve for w*, z* using separate risk and gainF
        self.opt_model = copy.deepcopy(optmodel)  # Ensure a separate instance
        self.w_star, self.z_star = self.opt_model(self.risk, self.gainF, self.cost, alpha=alpha, Q=Q)

        self.w_star = torch.tensor(self.w_star, dtype=torch.float)
        self.z_star = torch.tensor(self.z_star, dtype=torch.float)

    def __len__(self):
        return len(self.feats)

    def __getitem__(self, idx):
        return self.feats, self.risk, self.gainF, self.cost, self.w_star, self.z_star

# %%
import torch.nn as nn

class CostPredictor(nn.Module):
    """
    Takes feats of shape (N, d_feat) => outputs c_hat of shape (N,)
    This is a small MLP row-by-row, returning an (N,) vector.
    """
    def __init__(self, d_feat):
        super().__init__()
        self.hidden = nn.Linear(d_feat, 64)  
        self.relu = nn.ReLU()
        self.out = nn.Linear(64, 1)
        self.softplus = nn.Softplus()

    def forward(self, x):
        # x shape: (N, d_feat)
        # We produce shape: (N,). We can do it in a batch approach:
        h = self.hidden(x)   # shape (N,16)
        r = self.relu(h)
        out = self.out(r)    # shape (N,1)
        return self.softplus(out).squeeze(-1)  # shape (N,)

# %%
# Create datasets
dataset_train = optDataset(solve_optimization, feats_train, risk_train,gainF_train, cost_train)
dataset_test = optDataset(solve_optimization, feats_test, risk_test, gainF_test, cost_test)

# Create dataloaders
dataloader_train = DataLoader(dataset_train, batch_size=1, shuffle=False)
dataloader_test = DataLoader(dataset_test, batch_size=1, shuffle=False)

# %%
class FairRiskPredictor(nn.Module):
    def __init__(self, input_dim, dropout_rate=0.1):
        super().__init__()
        self.model = nn.Sequential(
            # First layer with batch normalization
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            
            # Second layer with batch normalization
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            
            # Third layer with batch normalization
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            
            # Output layer
            nn.Linear(32, 1),
            nn.Softplus()
        )
        
        # Initialize weights using He initialization
        for m in self.model:
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, mode='fan_in', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
                    
    def forward(self, x):
        return self.model(x).squeeze(-1)

# %%
def regret(predmodel, optmodel, dataloader, alpha=alpha, Q=Q):
    predmodel.eval()
    feats, risk, gainF, cost, opt_sol, opt_val = next(iter(dataloader))

    if torch.cuda.is_available():
        feats, risk, gainF, cost, opt_sol, opt_val = feats.cuda(), risk.cuda(), gainF.cuda(), cost.cuda(), opt_sol.cuda(), opt_val.cuda()

    # predict new rg
    with torch.no_grad():
        pred_risk = predmodel(feats)


    risk = risk.detach().to('cpu').numpy()
    pred_risk = pred_risk.detach().to('cpu').numpy()
    pred_risk = pred_risk.clip(min=0.001)

    gainF = gainF.detach().to('cpu').numpy()
    cost = cost.detach().to('cpu').numpy()

    if optmodel is compute_d_star_closed_form:
        pred_sol = optmodel(gainF, pred_risk, cost, alpha, Q)
        
    else:
        pred_sol, _ = optmodel(gainF, pred_risk, cost, alpha, Q)
    pred_obj = AlphaFairness(gainF * risk * pred_sol, alpha)


    normalized_regret = (opt_val - pred_obj) / (abs(opt_val) + 1e-7)

    return normalized_regret

# %%
predmodel = FairRiskPredictor(
    input_dim=feats_train.shape[1]
).to(device)

# %%
regret3 = regret(predmodel, solve_optimization, dataloader_test, alpha, Q)
regret3
# Out:
# tensor([0.1804], device='cuda:0')

# %%
class RegretLossFunction(Function):
    @staticmethod
    def forward(ctx, optmodel, cost, gainF, pred_r, true_r, true_obj, Q, alpha):
        batch_size = pred_r.size(0)
        losses = torch.zeros(batch_size, device=pred_r.device)
        
        pred_r_np = pred_r.detach().cpu().numpy()
        true_r_np = true_r.detach().cpu().numpy()
        cost_np = cost.detach().cpu().numpy()
        gainF_np = gainF.detach().cpu().numpy()
        
        for i in range(batch_size):
            sol = compute_d_star_closed_form(gainF_np[i], pred_r_np[i], cost_np[i], alpha, Q)
            obj = AlphaFairness(gainF_np[i] * true_r_np[i] * sol, alpha)

            losses[i] = true_obj[i] - obj
        
        # Store necessary tensors for backward pass
        ctx.save_for_backward(gainF, pred_r, true_r, cost, true_obj)
        ctx.optmodel = optmodel
        ctx.Q = Q
        ctx.alpha = alpha
        ctx.losses = losses

        return losses.mean().to(pred_r.device)

    @staticmethod
    def backward(ctx, grad_output):

        gainF, pred_r, true_r, cost, true_obj = ctx.saved_tensors
        optmodel = ctx.optmodel
        Q = ctx.Q
        alpha = ctx.alpha

        batch_size = pred_r.size(0)
        grad_pred_r = torch.zeros_like(pred_r)
        epsilon = 1e-5

        for i in range(batch_size):
            pred_r_np = pred_r[i].detach().cpu().numpy()
            cost_np = cost[i].detach().cpu().numpy()
            true_r_np = true_r[i].detach().cpu().numpy()

            # Analytical
            closed_grad_d_r = compute_gradient_closed_form(gainF[i].detach().cpu().numpy(), pred_r_np, cost_np, alpha, Q)
            closed_grad_diag = np.diag(closed_grad_d_r)
            gradient = np.zeros_like(pred_r_np)
            for j in range(pred_r_np.size):
                perturbed_pred_r_plus = np.copy(pred_r_np)
                perturbed_pred_r_minus = np.copy(pred_r_np)
                perturbed_pred_r_plus[j] += epsilon
                perturbed_pred_r_minus[j] -= epsilon
                
                # Compute loss with perturbed pred_r
                sol_plus = compute_d_star_closed_form(gainF[i].detach().cpu().numpy(), perturbed_pred_r_plus, cost_np, alpha, Q)
                sol_minus = compute_d_star_closed_form(gainF[i].detach().cpu().numpy(), perturbed_pred_r_minus, cost_np, alpha, Q)
                
                obj_perturbed_plus = AlphaFairness(gainF[i].detach().cpu().numpy() * true_r_np * sol_plus, alpha)
                obj_perturbed_minus = AlphaFairness(gainF[i].detach().cpu().numpy() * true_r_np * sol_minus, alpha)
                
                loss_perturbed_plus = true_obj[i].item() - obj_perturbed_plus
                loss_perturbed_minus = true_obj[i].item() - obj_perturbed_minus
                
                # Finite difference approximation
                gradient[j] = (loss_perturbed_plus - loss_perturbed_minus) / (2 * epsilon)
            closed_grad_d_r = torch.tensor(closed_grad_diag, device=pred_r.device, requires_grad=True)

            grad_pred_r[i] = torch.tensor(closed_grad_diag, device=pred_r.device)
        grad_pred_r = grad_output.view(-1, 1) * grad_pred_r

        return None, None, None, grad_pred_r, None, None, None, None

class RegretLoss(nn.Module):
    def __init__(self, optmodel, Q=Q, alpha=alpha):
        super(RegretLoss, self).__init__()
        self.optmodel = optmodel
        self.Q = Q
        self.alpha = alpha

    def forward(self, gainF, pred_r, true_r, cost, true_obj):
        return RegretLossFunction.apply(self.optmodel, gainF, cost, pred_r, true_r, true_obj, self.Q, self.alpha)

# %%
2
# Out:
# 2

# %%
import time

def trainModel(predmodel, optmodel, loss_func, loader_train, loader_test, num_epochs=10, lr=1e-3):
    optimizer = optim.Adam(predmodel.parameters(), lr=lr)
    mse_loss_func = nn.MSELoss()
    print('inital regret:', regret(predmodel, optmodel, loader_test, alpha=alpha, Q=Q))
    print("Training model...")
    
    predmodel.train()

    train_loss_log = []
    test_regret_log = []
    mse_loss_log = []

    elapsed = 0

    for epoch in range(num_epochs):
        tick = time.time()

    
        for data in loader_train:
            feats, risk, gainF, cost, opt_sol, opt_val = data
        if torch.cuda.is_available():
            feats, risk, gainF, cost, opt_sol, opt_val = feats.cuda(), risk.cuda(), gainF.cuda(), cost.cuda(), opt_sol.cuda(), opt_val.cuda()
        
        # predict new risk
        pred_risk = predmodel(feats)

        pred_risk = pred_risk.clip(min=0.001)
        loss_func = RegretLoss(optmodel, Q=Q, alpha=alpha)
        loss = loss_func(gainF, pred_risk, risk, cost, opt_val) 
        mse_loss = mse_loss_func(pred_risk, risk)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        tock = time.time()
        elapsed += tock - tick
        train_loss_log.append(loss.item())
        mse_loss_log.append(mse_loss.item())

        test_regret = regret(predmodel, optmodel, loader_test, alpha=alpha, Q=Q)
        test_regret_log.append(test_regret)
        print(f"Epoch {epoch + 1:2}, MSE:{mse_loss.item():.4f} Loss: {loss.item():9.4f}, Regret: {float(test_regret) * 100:7.4f}%, Elapsed: {elapsed:.2f}s")

    predmodel.eval()
    return test_regret_log, train_loss_log, mse_loss_log

# %%
test_regret_log, train_loss_log, mse_loss_log = trainModel(predmodel, solve_optimization, RegretLoss, dataloader_train, dataloader_test, num_epochs=50, lr=1e-3)
# Out:
# inital regret: tensor([0.1804], device='cuda:0')
# Training model...
# Epoch  1, MSE:58.6219 Loss: 13508.8008, Regret: 16.9480%, Elapsed: 0.07s
# Epoch  2, MSE:56.0067 Loss: 11478.5117, Regret: 16.1507%, Elapsed: 0.14s
# Epoch  3, MSE:52.8758 Loss: 10961.0049, Regret: 15.5568%, Elapsed: 0.22s
# Epoch  4, MSE:49.8435 Loss: 10565.8291, Regret: 15.0664%, Elapsed: 0.29s
# Epoch  5, MSE:47.0682 Loss: 10276.4482, Regret: 14.6592%, Elapsed: 0.35s
# Epoch  6, MSE:44.4466 Loss: 10049.3877, Regret: 14.3055%, Elapsed: 0.42s
# Epoch  7, MSE:41.9850 Loss: 9883.9082, Regret: 14.0269%, Elapsed: 0.48s
# Epoch  8, MSE:39.7005 Loss: 9787.9150, Regret: 13.8006%, Elapsed: 0.55s
# Epoch  9, MSE:37.5539 Loss: 9732.1289, Regret: 13.6118%, Elapsed: 0.62s
# Epoch 10, MSE:35.6088 Loss: 9697.9482, Regret: 13.4494%, Elapsed: 0.69s
# Epoch 11, MSE:33.8592 Loss: 9678.5684, Regret: 13.2719%, Elapsed: 0.75s
# Epoch 12, MSE:32.3073 Loss: 9683.6084, Regret: 13.1091%, Elapsed: 0.82s
# Epoch 13, MSE:30.9826 Loss: 9709.0762, Regret: 12.9670%, Elapsed: 0.88s
# Epoch 14, MSE:29.8976 Loss: 9751.1680, Regret: 12.8387%, Elapsed: 0.94s
# Epoch 15, MSE:29.0506 Loss: 9815.5771, Regret: 12.7378%, Elapsed: 1.02s
# Epoch 16, MSE:28.4831 Loss: 9922.3223, Regret: 12.6418%, Elapsed: 1.10s
# Epoch 17, MSE:28.2194 Loss: 10035.8438, Regret: 12.5577%, Elapsed: 1.19s
# Epoch 18, MSE:28.3351 Loss: 10151.7197, Regret: 12.4848%, Elapsed: 1.27s
# Epoch 19, MSE:28.8475 Loss: 10266.3877, Regret: 12.4214%, Elapsed: 1.36s
# Epoch 20, MSE:29.8107 Loss: 10376.7402, Regret: 12.3781%, Elapsed: 1.43s
# Epoch 21, MSE:31.3095 Loss: 10487.2207, Regret: 12.3561%, Elapsed: 1.50s
# Epoch 22, MSE:33.4046 Loss: 10592.6680, Regret: 12.3407%, Elapsed: 1.57s
# Epoch 23, MSE:36.1508 Loss: 10691.0713, Regret: 12.3336%, Elapsed: 1.65s
# Epoch 24, MSE:39.5924 Loss: 10783.7305, Regret: 12.3295%, Elapsed: 1.71s
# Epoch 25, MSE:43.8122 Loss: 10867.4980, Regret: 12.3261%, Elapsed: 1.78s
# Epoch 26, MSE:48.8920 Loss: 10940.1250, Regret: 12.3251%, Elapsed: 1.85s
# Epoch 27, MSE:54.9262 Loss: 11002.6885, Regret: 12.3248%, Elapsed: 1.92s
# Epoch 28, MSE:62.0230 Loss: 11065.6924, Regret: 12.3182%, Elapsed: 1.98s
# Epoch 29, MSE:70.2790 Loss: 11125.3643, Regret: 12.3177%, Elapsed: 2.04s
# Epoch 30, MSE:79.8276 Loss: 11182.8691, Regret: 12.3108%, Elapsed: 2.11s
# Epoch 31, MSE:90.7615 Loss: 11237.3164, Regret: 12.3098%, Elapsed: 2.17s
# Epoch 32, MSE:103.2798 Loss: 11288.1318, Regret: 12.3118%, Elapsed: 2.23s
# Epoch 33, MSE:117.5292 Loss: 11332.1055, Regret: 12.3169%, Elapsed: 2.29s
# Epoch 34, MSE:133.6579 Loss: 11370.6348, Regret: 12.3238%, Elapsed: 2.36s
# Epoch 35, MSE:151.8595 Loss: 11410.4434, Regret: 12.3304%, Elapsed: 2.41s
# Epoch 36, MSE:172.4018 Loss: 11443.6758, Regret: 12.3359%, Elapsed: 2.47s
# Epoch 37, MSE:195.5112 Loss: 11471.8926, Regret: 12.3386%, Elapsed: 2.54s
# Epoch 38, MSE:221.4982 Loss: 11495.4531, Regret: 12.3402%, Elapsed: 2.60s
# Epoch 39, MSE:250.5556 Loss: 11516.2832, Regret: 12.3379%, Elapsed: 2.66s
# Epoch 40, MSE:283.0168 Loss: 11534.5479, Regret: 12.3344%, Elapsed: 2.72s
# Epoch 41, MSE:319.1821 Loss: 11551.1104, Regret: 12.3309%, Elapsed: 2.78s
# Epoch 42, MSE:359.3363 Loss: 11564.0391, Regret: 12.3267%, Elapsed: 2.84s
# Epoch 43, MSE:403.9254 Loss: 11573.2676, Regret: 12.3237%, Elapsed: 2.90s
# Epoch 44, MSE:453.2512 Loss: 11579.5664, Regret: 12.3142%, Elapsed: 2.96s
# Epoch 45, MSE:507.8417 Loss: 11582.6738, Regret: 12.3039%, Elapsed: 3.02s
# Epoch 46, MSE:568.3422 Loss: 11582.7832, Regret: 12.2932%, Elapsed: 3.07s
# Epoch 47, MSE:635.2560 Loss: 11580.0947, Regret: 12.2834%, Elapsed: 3.13s
# Epoch 48, MSE:708.9678 Loss: 11577.4355, Regret: 12.2746%, Elapsed: 3.21s
# Epoch 49, MSE:790.4231 Loss: 11575.0771, Regret: 12.2685%, Elapsed: 3.28s
# Epoch 50, MSE:880.3095 Loss: 11570.2021, Regret: 12.2616%, Elapsed: 3.34s

# %%
# inital regret: tensor([0.0688], device='cuda:0')
# Training model...
# Epoch  1, MSE:62.4383 Loss: 2405.3379, Regret:  6.8787%, Elapsed: 5.40s
# Epoch  2, MSE:62.4594 Loss: 2404.4006, Regret:  6.8781%, Elapsed: 10.81s
# Epoch  3, MSE:62.4374 Loss: 2399.4258, Regret:  6.8746%, Elapsed: 16.27s
# Epoch  4, MSE:62.3619 Loss: 2387.4167, Regret:  6.8653%, Elapsed: 21.70s
# Epoch  5, MSE:62.1986 Loss: 2365.2031, Regret:  6.8540%, Elapsed: 27.17s
# Epoch  6, MSE:61.9028 Loss: 2326.9358, Regret:  6.8453%, Elapsed: 32.71s
# Epoch  7, MSE:61.4184 Loss: 2276.1331, Regret:  6.8441%, Elapsed: 38.11s
# Epoch  8, MSE:60.9244 Loss: 2234.8442, Regret:  6.8355%, Elapsed: 43.49s
# Epoch  9, MSE:60.0672 Loss: 2189.2078, Regret:  6.8114%, Elapsed: 48.86s
# Epoch 10, MSE:58.7593 Loss: 2150.7976, Regret:  6.7866%, Elapsed: 54.17s
# Epoch 11, MSE:57.2580 Loss: 2126.7524, Regret:  6.7533%, Elapsed: 59.43s
# Epoch 12, MSE:55.2830 Loss: 2112.1602, Regret:  6.7238%, Elapsed: 64.70s
# Epoch 13, MSE:53.6938 Loss: 2104.2739, Regret:  6.7105%, Elapsed: 70.03s
# Epoch 14, MSE:53.0619 Loss: 2098.4209, Regret:  6.6803%, Elapsed: 75.35s
# Epoch 15, MSE:51.7995 Loss: 2093.3318, Regret:  6.6275%, Elapsed: 80.52s
# Epoch 16, MSE:49.4821 Loss: 2091.5254, Regret:  6.5887%, Elapsed: 85.77s
# Epoch 17, MSE:48.1513 Loss: 2088.3660, Regret:  6.5876%, Elapsed: 91.03s
# Epoch 18, MSE:48.5077 Loss: 2082.6189, Regret:  6.5512%, Elapsed: 96.31s
# Epoch 19, MSE:47.2929 Loss: 2080.0076, Regret:  6.5278%, Elapsed: 101.52s
# Epoch 20, MSE:46.7540 Loss: 2076.0295, Regret:  6.5328%, Elapsed: 106.70s
# Epoch 21, MSE:47.5876 Loss: 2069.7705, Regret:  6.5460%, Elapsed: 111.98s
# Epoch 22, MSE:48.7136 Loss: 2063.8230, Regret:  6.5338%, Elapsed: 117.19s
# Epoch 23, MSE:48.7314 Loss: 2059.7346, Regret:  6.5265%, Elapsed: 122.40s
# Epoch 24, MSE:48.9931 Loss: 2055.6780, Regret:  6.5022%, Elapsed: 127.58s
# Epoch 25, MSE:48.6012 Loss: 2052.2583, Regret:  6.4566%, Elapsed: 132.78s
# Epoch 26, MSE:47.2990 Loss: 2050.2693, Regret:  6.4300%, Elapsed: 137.99s
# Epoch 27, MSE:46.7437 Loss: 2047.1069, Regret:  6.3808%, Elapsed: 143.19s
# Epoch 28, MSE:45.1330 Loss: 2045.8494, Regret:  6.3341%, Elapsed: 148.40s
# Epoch 29, MSE:43.6590 Loss: 2044.6907, Regret:  6.3234%, Elapsed: 153.61s
# Epoch 30, MSE:41.1862 Loss: 2045.7910, Regret:  6.3483%, Elapsed: 158.84s

# %%
test_regret_log[:2], train_loss_log[:2], mse_loss_log[:2]
# Out:
# ([tensor([0.1695], device='cuda:0'), tensor([0.1615], device='cuda:0')],
#  [13508.80078125, 11478.51171875],
#  [58.62189483642578, 56.006736755371094])

# %%
train_loss_log_values = [loss for loss in train_loss_log]
test_regret_log_values = [regret.detach().cpu().numpy() for regret in test_regret_log]
mse_loss_log_values = [loss for loss in mse_loss_log]

# %%
def visLearningCurve(loss_log, loss_log_regret, mse_loss_log):
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 4))

    # Plot original loss log
    ax1.plot(loss_log, color="c", lw=2)
    ax1.tick_params(axis="both", which="major", labelsize=12)
    ax1.set_xlabel("Iters", fontsize=16)
    ax1.set_ylabel("Loss", fontsize=16)
    ax1.set_title("Training Loss Curve", fontsize=16)
    # Plot regret log
    ax2.plot(loss_log_regret, color="royalblue", ls="--", alpha=0.7, lw=2)
    ax2.tick_params(axis="both", which="major", labelsize=12)
    ax2.set_xlabel("Epochs", fontsize=16)
    ax2.set_ylabel("Regret", fontsize=16)
    ax2.set_title("Learning Curve (Test Regret)", fontsize=16)

    # Plot new MSE loss log
    ax3.plot(mse_loss_log, color="orange", lw=2)
    ax3.tick_params(axis="both", which="major", labelsize=12)
    ax3.set_xlabel("Iters", fontsize=16)
    ax3.set_ylabel("MSE Loss", fontsize=16)
    ax3.set_title("Learning Curve (MSE Loss)", fontsize=16)

    plt.tight_layout()
    plt.show()

# %%
visLearningCurve(train_loss_log_values, test_regret_log_values, mse_loss_log_values)

# %%
raise ValueError("Stop here")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 raise ValueError("Stop here")
#
# ValueError: Stop here

# %%
import torch
from torch import nn
import numpy as np

class RegretLossFunction(torch.autograd.Function):
    @staticmethod
    def forward(ctx, pred_risk, true_risk, gainF, cost, alpha, Q):
        """
        Forward pass computing regret loss with normalized inputs
        """
        # Ensure inputs are 2D
        if pred_risk.dim() == 1:
            pred_risk = pred_risk.unsqueeze(0)
            true_risk = true_risk.unsqueeze(0)
            gainF = gainF.unsqueeze(0)
            cost = cost.unsqueeze(0)
            
        batch_size, N = pred_risk.shape
        
        # Convert to numpy
        pred_risk_np = pred_risk.detach().cpu().numpy()
        true_risk_np = true_risk.detach().cpu().numpy()
        gainF_np = gainF.detach().cpu().numpy()
        cost_np = cost.detach().cpu().numpy()
        
        # Normalize predictions to be in similar range as true risk
        risk_scale = np.mean(true_risk_np) / np.mean(pred_risk_np)
        pred_risk_np = pred_risk_np * risk_scale
        
        regrets = np.zeros(batch_size)
        d_preds = []
        w_preds = []
        w_trues = []
        
        for i in range(batch_size):
            # Compute optimal decisions
            d_pred = compute_d_star_closed_form(gainF_np[i], pred_risk_np[i], cost_np[i], alpha, Q)
            d_true = compute_d_star_closed_form(gainF_np[i], true_risk_np[i], cost_np[i], alpha, Q)
            
            # Calculate utilities and welfare
            util_pred = gainF_np[i] * true_risk_np[i] * d_pred
            util_true = gainF_np[i] * true_risk_np[i] * d_true
            
            welfare_pred = AlphaFairness(util_pred, alpha)
            welfare_true = AlphaFairness(util_true, alpha)
            
            regrets[i] = welfare_true - welfare_pred
            d_preds.append(d_pred)
            w_preds.append(welfare_pred)
            w_trues.append(welfare_true)
        
        # Store values needed for backward pass
        ctx.save_for_backward(pred_risk, true_risk, gainF, cost)
        ctx.risk_scale = risk_scale
        ctx.alpha = alpha
        ctx.Q = Q
        ctx.d_preds = d_preds
        ctx.N = N
        
        return torch.tensor(regrets, dtype=torch.float32, device=pred_risk.device)
    
    @staticmethod
    def backward(ctx, grad_output):
        pred_risk, true_risk, gainF, cost = ctx.saved_tensors
        risk_scale = ctx.risk_scale
        alpha = ctx.alpha
        Q = ctx.Q
        d_preds = ctx.d_preds
        N = ctx.N
        batch_size = pred_risk.shape[0]
        
        # Convert to numpy
        pred_risk_np = pred_risk.detach().cpu().numpy()
        gainF_np = gainF.detach().cpu().numpy()
        cost_np = cost.detach().cpu().numpy()
        
        grad_pred_risk = np.zeros((batch_size, N))
        
        for i in range(batch_size):
            # Compute gradients with scaling
            scaled_pred_risk = pred_risk_np[i] * risk_scale
            jacobian = compute_gradient_closed_form(gainF_np[i], scaled_pred_risk, cost_np[i], alpha, Q)
            
            # Apply chain rule: include scaling factor in gradient
            grad_pred_risk[i] = -grad_output[i].item() * jacobian.sum(axis=0) * risk_scale
            
            # Scale gradients to prevent vanishing/exploding
            grad_norm = np.linalg.norm(grad_pred_risk[i])
            if grad_norm > 0:
                target_norm = 1.0  # Target gradient norm
                grad_pred_risk[i] = grad_pred_risk[i] * (target_norm / grad_norm)
        
        # Convert to tensor
        grad_pred_risk = torch.tensor(grad_pred_risk, dtype=torch.float32, device=pred_risk.device)
        
        return grad_pred_risk, None, None, None, None, None

class RegretLoss(nn.Module):
    def __init__(self, alpha, Q):
        super().__init__()
        self.alpha = alpha
        self.Q = Q
        
    def forward(self, pred_risk, true_risk, gainF, cost):
        return RegretLossFunction.apply(pred_risk, true_risk, gainF, cost, self.alpha, self.Q)

# %%
# # Initialize the RegretLoss with the predictor model, optimization model, and dataloader
# regret_loss = RegretLoss(pred_risk, true_risk)

# # Test the RegretLoss
# loss = regret_loss()
# print(f"Regret Loss: {loss.item()}")

# %%
import time

def trainModel(predmodel, optmodel, loss_func, loader_train, loader_test, num_epochs=10, lr=1e-3):
    optimizer = optim.Adam(predmodel.parameters(), lr=lr)
    
    predmodel.train()

    train_loss_log = []
    test_regret_log = [regret(predmodel, optmodel, loader_test, alpha=alpha, Q=Q)]
    mse_loss_log = []

    elapsed = 0

    for epoch in range(num_epochs):
        tick = time.time()

        for data in loader_train:
            feats, risk, gainF, cost, opt_sol, opt_val = data
            if torch.cuda.is_available():
                feats, risk, gainF, cost, opt_sol, opt_val = feats.cuda(), risk.cuda(), gainF.cuda(), cost.cuda(), opt_sol.cuda(), opt_val.cuda()
            
            # predict new risk
            pred_risk = predmodel(feats)
            loss = loss_func(pred_risk, risk)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            tock = time.time()
            elapsed += tock - tick
            train_loss_log.append(loss.item())

        test_regret = regret(predmodel, optmodel, loader_test, alpha=alpha, Q=Q)
        test_regret_log.append(test_regret)
        print(f"Epoch {epoch + 1:2},  Loss: {loss.item():9.4f}, Regret: {float(test_regret) * 100:7.4f}%, Elapsed: {elapsed:.2f}s")

    predmodel.eval()
    return test_regret_log, train_loss_log

# %%
def train_with_regret(predmodel, optmodel, loader_train, loader_test, num_epochs=50, lr=1e-4, weight_decay=1e-5, alpha=alpha, Q=Q):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    predmodel.to(device)
    
    # Initialize optimizer with smaller learning rate and gradient clipping
    optimizer = optim.AdamW(predmodel.parameters(), lr=lr, weight_decay=weight_decay)
    criterion = RegretLoss(alpha=alpha, Q=Q)
    
    train_loss_log = []
    test_regret_log = []
    best_regret = float('inf')
    best_model_state = None
    patience = 5
    patience_counter = 0
    
    for epoch in range(num_epochs):
        predmodel.train()
        epoch_losses = []
        
        for feats, risk, gainF, cost, _, _ in loader_train:
            feats = feats.to(device)
            risk = risk.to(device)
            gainF = gainF.to(device)
            cost = cost.to(device)
            
            # Forward pass
            optimizer.zero_grad()
            pred_risk = predmodel(feats)
            
            # Print prediction statistics
            print(f"\nPrediction stats:")
            print(f"pred_risk - Mean: {pred_risk.mean():.4f}, Min: {pred_risk.min():.4f}, Max: {pred_risk.max():.4f}")
            print(f"true_risk - Mean: {risk.mean():.4f}, Min: {risk.min():.4f}, Max: {risk.max():.4f}")
            
            # Calculate regret loss
            loss = criterion(pred_risk, risk, gainF, cost).mean()
            
            # Check for NaN loss
            if torch.isnan(loss):
                print("NaN loss detected!")
                continue
                
            # Backward pass with gradient clipping
            loss.backward()
            
            # Print gradient norms for debugging
            total_norm = 0.0
            for p in predmodel.parameters():
                if p.grad is not None:
                    param_norm = p.grad.data.norm(2)
                    total_norm += param_norm.item() ** 2
            total_norm = total_norm ** 0.5
            print(f"Gradient norm before clipping: {total_norm:.4f}")
            
            # Clip gradients
            torch.nn.utils.clip_grad_norm_(predmodel.parameters(), max_norm=1.0)
            
            optimizer.step()
            
            # Ensure predictions stay positive
            with torch.no_grad():
                for p in predmodel.parameters():
                    if p.requires_grad:
                        p.data.clamp_(min=0.001)
            
            epoch_losses.append(loss.item())
        
        avg_train_loss = np.mean(epoch_losses)
        train_loss_log.append(avg_train_loss)
        
        # Evaluate
        predmodel.eval()
        with torch.no_grad():
            test_regret = regret(predmodel, solve_optimization, loader_test)
            test_regret_log.append(test_regret)
            
            # Early stopping logic
            if test_regret < best_regret:
                best_regret = test_regret
                best_model_state = predmodel.state_dict().copy()
                patience_counter = 0
            else:
                patience_counter += 1
                
            if patience_counter >= patience:
                print("Early stopping triggered!")
                break
        
        
        print(f"Epoch {epoch + 1}")
        print(f"Train Loss: {avg_train_loss:.4f}")
        print(f"Test Regret: {float(test_regret):.4f}")
        print(f"Best Regret: {float(best_regret):.4f}")
    
    # Restore best model
    if best_model_state is not None:
        predmodel.load_state_dict(best_model_state)
    
    return train_loss_log, test_regret_log

# %%
def train_risk_predictor(predmodel, optmodel, loss_func, loader_train, loader_test, 
                       num_epochs=50, lr=3e-4, weight_decay=1e-5,
                       patience=5, min_delta=1e-4, alpha=alpha, Q=Q):
    """
    Enhanced training function with early stopping, learning rate scheduling, and regret tracking
    """

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    predmodel.to(device)
    optmodel_train = copy.deepcopy(optmodel)
    optmodel_test = copy.deepcopy(optmodel)

    # Initialize optimizer with weight decay
    optimizer = optim.AdamW(predmodel.parameters(), lr=lr, weight_decay=weight_decay)
    
    # # Learning rate scheduler
    # scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', 
    #                                                 factor=0.5, patience=3, 
    #                                                 verbose=True)
    
    # Initialize tracking lists
    train_loss_log = []
    test_regret_log = [regret(predmodel, optmodel, loader_test, alpha=alpha, Q=Q)]
    
    # Training setup
    best_loss = float('inf')
    best_model_state = None
    # patience_counter = 0
    elapsed = 0
    
    for epoch in range(num_epochs):
        tick = time.time()
        predmodel.train()
        epoch_losses = []
        
        for data in loader_train:
            feats, risk, gainF, cost, opt_sol, opt_val = data
            if torch.cuda.is_available():
                feats = feats.cuda()
                risk = risk.cuda()
                gainF = gainF.cuda()
                cost = cost.cuda()
                opt_sol = opt_sol.cuda()
                opt_val = opt_val.cuda()
            
            # Forward pass
            optimizer.zero_grad()
            pred_risk = predmodel(feats)
            # regret loss
            if loss_func == 'regret_loss':
                loss = RegretLoss(pred_risk, risk)
            if loss_func == 'mse':
                loss_fn = nn.MSELoss()
                loss = loss_fn(pred_risk, risk)

            loss.backward()
            optimizer.step()
            epoch_losses.append(loss.item())
        
        avg_train_loss = np.mean(epoch_losses)
        train_loss_log.append(avg_train_loss)

        predmodel.eval()
        test_regret = regret(predmodel, optmodel_test, loader_test, alpha=alpha, Q=Q)
        test_regret_log.append(test_regret)
        
        # Calculate elapsed time
        tock = time.time()
        elapsed += tock - tick
        
        # Print progress
        print(f"Epoch {epoch + 1:2}, Train Loss: {avg_train_loss:.4f}, "
            f"Test Regret: {float(test_regret):.4f}, Elapsed: {elapsed:.2f}s")
    
    
    # Restore best model
    if best_model_state is not None:
        predmodel.load_state_dict(best_model_state)
        
    predmodel.eval()
    return test_regret_log, train_loss_log

# %%
regret(predmodel, solve_optimization, dataloader_test, alpha=alpha, Q=Q)
# Out:
# tensor([0.2117], device='cuda:0')

# %%
# raise ValueError("Stop here")
# criterion = 'mse'
# logs = train_risk_predictor(predmodel, solve_optimization, criterion, dataloader_train, dataloader_test, num_epochs=10, lr=1e-3, weight_decay=1e-5, patience=5, min_delta=1e-4, alpha=alpha, Q=Q)

# %%
criterion = RegretLoss(alpha=alpha, Q=Q)
optmodel = compute_d_star_closed_form

# %%
regret03 = regret(predmodel, optmodel, dataloader_test, alpha, Q)
regret03
# Out:
# tensor([0.2117], device='cuda:0')

# %%
logs = train_with_regret(predmodel, optmodel, dataloader_train, dataloader_test, num_epochs=5, lr=1e-3, weight_decay=1e-5, alpha=alpha, Q=Q)
# Out:
# Prediction stats:
# pred_risk - Mean: 0.6931, Min: 0.6930, Max: 0.6933
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4798
#
# Prediction stats:
# pred_risk - Mean: 0.6963, Min: 0.6938, Max: 0.7357
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3078
#
# Prediction stats:
# pred_risk - Mean: 0.6967, Min: 0.6939, Max: 0.7388
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6088
#
# Prediction stats:
# pred_risk - Mean: 0.6978, Min: 0.6942, Max: 0.7530
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.7702
#
# Prediction stats:
# pred_risk - Mean: 0.6991, Min: 0.6947, Max: 0.7640
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5036
#
# Prediction stats:
# pred_risk - Mean: 0.6996, Min: 0.6949, Max: 0.7715
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5459
#
# Prediction stats:
# pred_risk - Mean: 0.7005, Min: 0.6952, Max: 0.7743
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.0901
#
# Prediction stats:
# pred_risk - Mean: 0.7011, Min: 0.6956, Max: 0.7796
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5030
#
# Prediction stats:
# pred_risk - Mean: 0.7010, Min: 0.6956, Max: 0.7794
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5136
#
# Prediction stats:
# pred_risk - Mean: 0.7013, Min: 0.6959, Max: 0.7829
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4866
#
# Prediction stats:
# pred_risk - Mean: 0.7018, Min: 0.6961, Max: 0.7958
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.7977
#
# Prediction stats:
# pred_risk - Mean: 0.7030, Min: 0.6967, Max: 0.8053
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5148
#
# Prediction stats:
# pred_risk - Mean: 0.7043, Min: 0.6973, Max: 0.8208
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5231
#
# Prediction stats:
# pred_risk - Mean: 0.7051, Min: 0.6975, Max: 0.8265
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5479
#
# Prediction stats:
# pred_risk - Mean: 0.7064, Min: 0.6982, Max: 0.8323
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5139
#
# Prediction stats:
# pred_risk - Mean: 0.7077, Min: 0.6985, Max: 0.8653
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4943
#
# Prediction stats:
# pred_risk - Mean: 0.7086, Min: 0.6990, Max: 0.8785
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5245
#
# Prediction stats:
# pred_risk - Mean: 0.7086, Min: 0.6991, Max: 0.8402
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4902
#
# Prediction stats:
# pred_risk - Mean: 0.7092, Min: 0.6995, Max: 0.8791
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4965
#
# Prediction stats:
# pred_risk - Mean: 0.7100, Min: 0.6997, Max: 0.8814
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5548
#
# Prediction stats:
# pred_risk - Mean: 0.7110, Min: 0.7002, Max: 0.8803
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5228
#
# Prediction stats:
# pred_risk - Mean: 0.7128, Min: 0.7008, Max: 0.9350
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6214
#
# Prediction stats:
# pred_risk - Mean: 0.7147, Min: 0.7014, Max: 0.9309
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6619
#
# Prediction stats:
# pred_risk - Mean: 0.7172, Min: 0.7026, Max: 0.9854
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4021
#
# Prediction stats:
# pred_risk - Mean: 0.7185, Min: 0.7032, Max: 0.9920
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5066
#
# Prediction stats:
# pred_risk - Mean: 0.7203, Min: 0.7040, Max: 1.0011
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.7847
#
# Prediction stats:
# pred_risk - Mean: 0.7212, Min: 0.7049, Max: 0.9791
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5343
#
# Prediction stats:
# pred_risk - Mean: 0.7227, Min: 0.7053, Max: 1.0467
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4332
#
# Prediction stats:
# pred_risk - Mean: 0.7250, Min: 0.7060, Max: 1.1304
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5460
#
# Prediction stats:
# pred_risk - Mean: 0.7254, Min: 0.7059, Max: 1.0593
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5402
#
# Prediction stats:
# pred_risk - Mean: 0.7256, Min: 0.7061, Max: 1.0606
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3399
#
# Prediction stats:
# pred_risk - Mean: 0.7243, Min: 0.7065, Max: 1.0452
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6845
#
# Prediction stats:
# pred_risk - Mean: 0.7231, Min: 0.7056, Max: 1.0251
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.8964
#
# Prediction stats:
# pred_risk - Mean: 0.7207, Min: 0.7047, Max: 0.9871
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5309
#
# Prediction stats:
# pred_risk - Mean: 0.7193, Min: 0.7054, Max: 1.0019
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5103
#
# Prediction stats:
# pred_risk - Mean: 0.7180, Min: 0.7045, Max: 0.9784
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4771
#
# Prediction stats:
# pred_risk - Mean: 0.7174, Min: 0.7045, Max: 0.9949
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3805
#
# Prediction stats:
# pred_risk - Mean: 0.7169, Min: 0.7041, Max: 0.9627
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3806
#
# Prediction stats:
# pred_risk - Mean: 0.7163, Min: 0.7034, Max: 0.9669
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4847
#
# Prediction stats:
# pred_risk - Mean: 0.7153, Min: 0.7037, Max: 0.9494
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.0469
#
# Prediction stats:
# pred_risk - Mean: 0.7147, Min: 0.7030, Max: 0.9510
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5373
#
# Prediction stats:
# pred_risk - Mean: 0.7139, Min: 0.7030, Max: 0.9274
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5380
#
# Prediction stats:
# pred_risk - Mean: 0.7129, Min: 0.7029, Max: 0.9154
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3676
#
# Prediction stats:
# pred_risk - Mean: 0.7121, Min: 0.7022, Max: 0.8973
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5681
#
# Prediction stats:
# pred_risk - Mean: 0.7113, Min: 0.7018, Max: 0.9108
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.0716
#
# Prediction stats:
# pred_risk - Mean: 0.7104, Min: 0.7017, Max: 0.8845
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.1240
#
# Prediction stats:
# pred_risk - Mean: 0.7096, Min: 0.7014, Max: 0.8652
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5127
#
# Prediction stats:
# pred_risk - Mean: 0.7089, Min: 0.7009, Max: 0.8693
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5399
#
# Prediction stats:
# pred_risk - Mean: 0.7084, Min: 0.7006, Max: 0.8560
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4516
#
# Prediction stats:
# pred_risk - Mean: 0.7077, Min: 0.7003, Max: 0.8713
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4446
#
# Prediction stats:
# pred_risk - Mean: 0.7071, Min: 0.7002, Max: 0.8321
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.8974
#
# Prediction stats:
# pred_risk - Mean: 0.7069, Min: 0.7000, Max: 0.8419
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4973
#
# Prediction stats:
# pred_risk - Mean: 0.7069, Min: 0.7001, Max: 0.8459
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6063
#
# Prediction stats:
# pred_risk - Mean: 0.7071, Min: 0.7004, Max: 0.8335
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4728
#
# Prediction stats:
# pred_risk - Mean: 0.7076, Min: 0.7002, Max: 0.8405
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5278
#
# Prediction stats:
# pred_risk - Mean: 0.7081, Min: 0.7007, Max: 0.8643
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 1.0480
#
# Prediction stats:
# pred_risk - Mean: 0.7083, Min: 0.7009, Max: 0.8443
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5125
#
# Prediction stats:
# pred_risk - Mean: 0.7091, Min: 0.7010, Max: 0.8735
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5319
#
# Prediction stats:
# pred_risk - Mean: 0.7089, Min: 0.7011, Max: 0.8476
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4861
#
# Prediction stats:
# pred_risk - Mean: 0.7091, Min: 0.7007, Max: 0.8671
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3830
#
# Prediction stats:
# pred_risk - Mean: 0.7090, Min: 0.7011, Max: 0.8760
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5520
#
# Prediction stats:
# pred_risk - Mean: 0.7094, Min: 0.7010, Max: 0.8767
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5982
#
# Prediction stats:
# pred_risk - Mean: 0.7092, Min: 0.7009, Max: 0.8735
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5015
#
# Prediction stats:
# pred_risk - Mean: 0.7092, Min: 0.7009, Max: 0.8765
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3934
#
# Prediction stats:
# pred_risk - Mean: 0.7088, Min: 0.7002, Max: 0.8671
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4611
#
# Prediction stats:
# pred_risk - Mean: 0.7087, Min: 0.7004, Max: 0.8792
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5685
#
# Prediction stats:
# pred_risk - Mean: 0.7085, Min: 0.6997, Max: 0.8653
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3206
#
# Prediction stats:
# pred_risk - Mean: 0.7086, Min: 0.7003, Max: 0.8440
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5440
#
# Prediction stats:
# pred_risk - Mean: 0.7084, Min: 0.7000, Max: 0.8464
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4464
#
# Prediction stats:
# pred_risk - Mean: 0.7085, Min: 0.7000, Max: 0.8660
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4704
#
# Prediction stats:
# pred_risk - Mean: 0.7081, Min: 0.7002, Max: 0.8577
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4261
#
# Prediction stats:
# pred_risk - Mean: 0.7080, Min: 0.6996, Max: 0.8626
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5120
#
# Prediction stats:
# pred_risk - Mean: 0.7077, Min: 0.6996, Max: 0.8920
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5250
#
# Prediction stats:
# pred_risk - Mean: 0.7073, Min: 0.6991, Max: 0.8484
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5485
#
# Prediction stats:
# pred_risk - Mean: 0.7072, Min: 0.6991, Max: 0.8635
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.1333
#
# Prediction stats:
# pred_risk - Mean: 0.7070, Min: 0.6990, Max: 0.8438
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5160
#
# Prediction stats:
# pred_risk - Mean: 0.7068, Min: 0.6985, Max: 0.8586
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6990
#
# Prediction stats:
# pred_risk - Mean: 0.7069, Min: 0.6986, Max: 0.8705
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5143
#
# Prediction stats:
# pred_risk - Mean: 0.7069, Min: 0.6986, Max: 0.8541
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4531
#
# Prediction stats:
# pred_risk - Mean: 0.7070, Min: 0.6983, Max: 0.8810
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4879
#
# Prediction stats:
# pred_risk - Mean: 0.7069, Min: 0.6982, Max: 0.8941
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5736
#
# Prediction stats:
# pred_risk - Mean: 0.7067, Min: 0.6983, Max: 0.8514
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5069
#
# Prediction stats:
# pred_risk - Mean: 0.7068, Min: 0.6981, Max: 0.8709
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4854
#
# Prediction stats:
# pred_risk - Mean: 0.7069, Min: 0.6981, Max: 0.8760
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5993
#
# Prediction stats:
# pred_risk - Mean: 0.7073, Min: 0.6981, Max: 0.8692
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5490
#
# Prediction stats:
# pred_risk - Mean: 0.7077, Min: 0.6983, Max: 0.9068
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6611
#
# Prediction stats:
# pred_risk - Mean: 0.7079, Min: 0.6983, Max: 0.8760
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4998
#
# Prediction stats:
# pred_risk - Mean: 0.7079, Min: 0.6982, Max: 0.9000
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5224
#
# Prediction stats:
# pred_risk - Mean: 0.7080, Min: 0.6981, Max: 0.8875
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4890
#
# Prediction stats:
# pred_risk - Mean: 0.7075, Min: 0.6980, Max: 0.8792
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5435
#
# Prediction stats:
# pred_risk - Mean: 0.7072, Min: 0.6976, Max: 0.8931
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5144
#
# Prediction stats:
# pred_risk - Mean: 0.7067, Min: 0.6972, Max: 0.8595
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5243
#
# Prediction stats:
# pred_risk - Mean: 0.7059, Min: 0.6970, Max: 0.8501
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5017
#
# Prediction stats:
# pred_risk - Mean: 0.7056, Min: 0.6968, Max: 0.8880
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4266
#
# Prediction stats:
# pred_risk - Mean: 0.7052, Min: 0.6964, Max: 0.8792
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3378
#
# Prediction stats:
# pred_risk - Mean: 0.7045, Min: 0.6962, Max: 0.8482
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3480
#
# Prediction stats:
# pred_risk - Mean: 0.7041, Min: 0.6959, Max: 0.8532
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5278
#
# Prediction stats:
# pred_risk - Mean: 0.7037, Min: 0.6959, Max: 0.8471
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3881
#
# Prediction stats:
# pred_risk - Mean: 0.7034, Min: 0.6958, Max: 0.8789
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5398
#
# Prediction stats:
# pred_risk - Mean: 0.7031, Min: 0.6957, Max: 0.8269
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5123
#
# Prediction stats:
# pred_risk - Mean: 0.7028, Min: 0.6956, Max: 0.8182
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5032
#
# Prediction stats:
# pred_risk - Mean: 0.7029, Min: 0.6956, Max: 0.8453
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5081
#
# Prediction stats:
# pred_risk - Mean: 0.7027, Min: 0.6956, Max: 0.8195
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4974
#
# Prediction stats:
# pred_risk - Mean: 0.7029, Min: 0.6956, Max: 0.8242
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5128
#
# Prediction stats:
# pred_risk - Mean: 0.7028, Min: 0.6955, Max: 0.8639
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5532
#
# Prediction stats:
# pred_risk - Mean: 0.7029, Min: 0.6957, Max: 0.8556
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4326
#
# Prediction stats:
# pred_risk - Mean: 0.7029, Min: 0.6957, Max: 0.8368
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.0197
#
# Prediction stats:
# pred_risk - Mean: 0.7030, Min: 0.6958, Max: 0.8406
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4108
#
# Prediction stats:
# pred_risk - Mean: 0.7027, Min: 0.6957, Max: 0.8321
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5122
#
# Prediction stats:
# pred_risk - Mean: 0.7024, Min: 0.6956, Max: 0.8598
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5209
#
# Prediction stats:
# pred_risk - Mean: 0.7021, Min: 0.6954, Max: 0.8281
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4527
#
# Prediction stats:
# pred_risk - Mean: 0.7019, Min: 0.6953, Max: 0.8261
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5326
#
# Prediction stats:
# pred_risk - Mean: 0.7015, Min: 0.6953, Max: 0.8327
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5007
#
# Prediction stats:
# pred_risk - Mean: 0.7013, Min: 0.6952, Max: 0.8093
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5249
#
# Prediction stats:
# pred_risk - Mean: 0.7014, Min: 0.6951, Max: 0.8305
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5511
#
# Prediction stats:
# pred_risk - Mean: 0.7013, Min: 0.6952, Max: 0.8066
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5139
#
# Prediction stats:
# pred_risk - Mean: 0.7019, Min: 0.6954, Max: 0.8344
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5488
#
# Prediction stats:
# pred_risk - Mean: 0.7021, Min: 0.6956, Max: 0.8419
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5232
#
# Prediction stats:
# pred_risk - Mean: 0.7021, Min: 0.6957, Max: 0.8289
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4677
#
# Prediction stats:
# pred_risk - Mean: 0.7023, Min: 0.6957, Max: 0.8410
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5621
#
# Prediction stats:
# pred_risk - Mean: 0.7019, Min: 0.6956, Max: 0.7977
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3578
#
# Prediction stats:
# pred_risk - Mean: 0.7022, Min: 0.6957, Max: 0.8261
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3737
#
# Prediction stats:
# pred_risk - Mean: 0.7020, Min: 0.6956, Max: 0.8412
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5369
#
# Prediction stats:
# pred_risk - Mean: 0.7019, Min: 0.6955, Max: 0.8219
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5448
#
# Prediction stats:
# pred_risk - Mean: 0.7016, Min: 0.6954, Max: 0.8208
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5203
#
# Prediction stats:
# pred_risk - Mean: 0.7014, Min: 0.6953, Max: 0.7960
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4751
#
# Prediction stats:
# pred_risk - Mean: 0.7015, Min: 0.6952, Max: 0.8146
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5492
#
# Prediction stats:
# pred_risk - Mean: 0.7015, Min: 0.6954, Max: 0.8044
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4082
#
# Prediction stats:
# pred_risk - Mean: 0.7014, Min: 0.6953, Max: 0.8122
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5243
#
# Prediction stats:
# pred_risk - Mean: 0.7017, Min: 0.6955, Max: 0.8245
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5217
#
# Prediction stats:
# pred_risk - Mean: 0.7019, Min: 0.6956, Max: 0.8176
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5393
#
# Prediction stats:
# pred_risk - Mean: 0.7021, Min: 0.6954, Max: 0.8384
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5057
#
# Prediction stats:
# pred_risk - Mean: 0.7019, Min: 0.6955, Max: 0.8228
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5374
#
# Prediction stats:
# pred_risk - Mean: 0.7020, Min: 0.6956, Max: 0.8147
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.8236
#
# Prediction stats:
# pred_risk - Mean: 0.7019, Min: 0.6955, Max: 0.8212
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4905
#
# Prediction stats:
# pred_risk - Mean: 0.7018, Min: 0.6955, Max: 0.8120
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4604
#
# Prediction stats:
# pred_risk - Mean: 0.7022, Min: 0.6956, Max: 0.8385
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5217
#
# Prediction stats:
# pred_risk - Mean: 0.7021, Min: 0.6954, Max: 0.8358
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6756
#
# Prediction stats:
# pred_risk - Mean: 0.7022, Min: 0.6957, Max: 0.8272
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5936
#
# Prediction stats:
# pred_risk - Mean: 0.7023, Min: 0.6956, Max: 0.8314
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3425
#
# Prediction stats:
# pred_risk - Mean: 0.7025, Min: 0.6956, Max: 0.8159
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6765
#
# Prediction stats:
# pred_risk - Mean: 0.7023, Min: 0.6955, Max: 0.8268
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4150
#
# Prediction stats:
# pred_risk - Mean: 0.7023, Min: 0.6953, Max: 0.8264
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5346
#
# Prediction stats:
# pred_risk - Mean: 0.7022, Min: 0.6955, Max: 0.8365
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5023
#
# Prediction stats:
# pred_risk - Mean: 0.7026, Min: 0.6954, Max: 0.8186
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5005
#
# Prediction stats:
# pred_risk - Mean: 0.7024, Min: 0.6954, Max: 0.8149
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6903
#
# Prediction stats:
# pred_risk - Mean: 0.7028, Min: 0.6955, Max: 0.8308
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5332
#
# Prediction stats:
# pred_risk - Mean: 0.7032, Min: 0.6957, Max: 0.8508
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4653
#
# Prediction stats:
# pred_risk - Mean: 0.7035, Min: 0.6958, Max: 0.8419
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 1.0140
#
# Prediction stats:
# pred_risk - Mean: 0.7036, Min: 0.6960, Max: 0.8390
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5181
#
# Prediction stats:
# pred_risk - Mean: 0.7043, Min: 0.6962, Max: 0.8653
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5277
#
# Prediction stats:
# pred_risk - Mean: 0.7046, Min: 0.6965, Max: 0.8441
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5768
#
# Prediction stats:
# pred_risk - Mean: 0.7052, Min: 0.6966, Max: 0.8584
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4668
#
# Prediction stats:
# pred_risk - Mean: 0.7055, Min: 0.6967, Max: 0.8394
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6173
#
# Prediction stats:
# pred_risk - Mean: 0.7055, Min: 0.6968, Max: 0.8310
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5558
#
# Prediction stats:
# pred_risk - Mean: 0.7060, Min: 0.6970, Max: 0.8685
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5576
#
# Prediction stats:
# pred_risk - Mean: 0.7057, Min: 0.6969, Max: 0.8423
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.1348
#
# Prediction stats:
# pred_risk - Mean: 0.7058, Min: 0.6969, Max: 0.8768
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5292
#
# Prediction stats:
# pred_risk - Mean: 0.7057, Min: 0.6968, Max: 0.8630
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5051
#
# Prediction stats:
# pred_risk - Mean: 0.7055, Min: 0.6967, Max: 0.8595
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4851
#
# Prediction stats:
# pred_risk - Mean: 0.7052, Min: 0.6967, Max: 0.8432
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4685
#
# Prediction stats:
# pred_risk - Mean: 0.7049, Min: 0.6966, Max: 0.8400
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4757
#
# Prediction stats:
# pred_risk - Mean: 0.7048, Min: 0.6964, Max: 0.8669
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5466
#
# Prediction stats:
# pred_risk - Mean: 0.7045, Min: 0.6964, Max: 0.8263
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5302
#
# Prediction stats:
# pred_risk - Mean: 0.7046, Min: 0.6963, Max: 0.8380
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5329
#
# Prediction stats:
# pred_risk - Mean: 0.7044, Min: 0.6963, Max: 0.8487
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5600
#
# Prediction stats:
# pred_risk - Mean: 0.7045, Min: 0.6963, Max: 0.8481
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5386
#
# Prediction stats:
# pred_risk - Mean: 0.7048, Min: 0.6964, Max: 0.8516
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5710
#
# Prediction stats:
# pred_risk - Mean: 0.7047, Min: 0.6964, Max: 0.8278
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5438
#
# Prediction stats:
# pred_risk - Mean: 0.7048, Min: 0.6964, Max: 0.8342
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6771
#
# Prediction stats:
# pred_risk - Mean: 0.7048, Min: 0.6965, Max: 0.8551
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6701
#
# Prediction stats:
# pred_risk - Mean: 0.7046, Min: 0.6963, Max: 0.8405
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.2806
#
# Prediction stats:
# pred_risk - Mean: 0.7045, Min: 0.6964, Max: 0.8338
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.1924
#
# Prediction stats:
# pred_risk - Mean: 0.7042, Min: 0.6963, Max: 0.8410
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5324
#
# Prediction stats:
# pred_risk - Mean: 0.7041, Min: 0.6962, Max: 0.8443
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4450
#
# Prediction stats:
# pred_risk - Mean: 0.7036, Min: 0.6959, Max: 0.8340
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5204
#
# Prediction stats:
# pred_risk - Mean: 0.7035, Min: 0.6960, Max: 0.8337
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4870
#
# Prediction stats:
# pred_risk - Mean: 0.7030, Min: 0.6959, Max: 0.8053
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4795
#
# Prediction stats:
# pred_risk - Mean: 0.7030, Min: 0.6958, Max: 0.8142
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5849
#
# Prediction stats:
# pred_risk - Mean: 0.7027, Min: 0.6957, Max: 0.8040
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4942
#
# Prediction stats:
# pred_risk - Mean: 0.7027, Min: 0.6954, Max: 0.8184
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5976
#
# Prediction stats:
# pred_risk - Mean: 0.7029, Min: 0.6957, Max: 0.8156
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4126
#
# Prediction stats:
# pred_risk - Mean: 0.7030, Min: 0.6959, Max: 0.8120
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.0820
#
# Prediction stats:
# pred_risk - Mean: 0.7033, Min: 0.6959, Max: 0.8301
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5115
#
# Prediction stats:
# pred_risk - Mean: 0.7036, Min: 0.6959, Max: 0.8290
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5043
#
# Prediction stats:
# pred_risk - Mean: 0.7037, Min: 0.6958, Max: 0.8322
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3945
#
# Prediction stats:
# pred_risk - Mean: 0.7037, Min: 0.6957, Max: 0.8437
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5244
#
# Prediction stats:
# pred_risk - Mean: 0.7033, Min: 0.6956, Max: 0.8189
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3531
#
# Prediction stats:
# pred_risk - Mean: 0.7032, Min: 0.6953, Max: 0.8172
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5429
#
# Prediction stats:
# pred_risk - Mean: 0.7030, Min: 0.6952, Max: 0.8144
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.2146
#
# Prediction stats:
# pred_risk - Mean: 0.7024, Min: 0.6950, Max: 0.8090
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3254
#
# Prediction stats:
# pred_risk - Mean: 0.7022, Min: 0.6948, Max: 0.7961
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5050
#
# Prediction stats:
# pred_risk - Mean: 0.7018, Min: 0.6947, Max: 0.7913
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4682
#
# Prediction stats:
# pred_risk - Mean: 0.7018, Min: 0.6946, Max: 0.8084
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6247
#
# Prediction stats:
# pred_risk - Mean: 0.7014, Min: 0.6944, Max: 0.8065
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5988
#
# Prediction stats:
# pred_risk - Mean: 0.7007, Min: 0.6942, Max: 0.8055
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5080
#
# Prediction stats:
# pred_risk - Mean: 0.7003, Min: 0.6940, Max: 0.7842
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5801
#
# Prediction stats:
# pred_risk - Mean: 0.7000, Min: 0.6940, Max: 0.7916
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5897
#
# Prediction stats:
# pred_risk - Mean: 0.6996, Min: 0.6939, Max: 0.7934
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3978
#
# Prediction stats:
# pred_risk - Mean: 0.6993, Min: 0.6939, Max: 0.7722
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5387
#
# Prediction stats:
# pred_risk - Mean: 0.6992, Min: 0.6939, Max: 0.7841
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4306
#
# Prediction stats:
# pred_risk - Mean: 0.6989, Min: 0.6939, Max: 0.7735
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5481
#
# Prediction stats:
# pred_risk - Mean: 0.6987, Min: 0.6939, Max: 0.7739
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4622
#
# Prediction stats:
# pred_risk - Mean: 0.6986, Min: 0.6938, Max: 0.7681
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5724
#
# Prediction stats:
# pred_risk - Mean: 0.6985, Min: 0.6938, Max: 0.7706
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4341
#
# Prediction stats:
# pred_risk - Mean: 0.6983, Min: 0.6938, Max: 0.7713
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3841
#
# Prediction stats:
# pred_risk - Mean: 0.6983, Min: 0.6938, Max: 0.7763
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5095
#
# Prediction stats:
# pred_risk - Mean: 0.6983, Min: 0.6938, Max: 0.7661
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5302
#
# Prediction stats:
# pred_risk - Mean: 0.6981, Min: 0.6938, Max: 0.7807
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4878
#
# Prediction stats:
# pred_risk - Mean: 0.6982, Min: 0.6938, Max: 0.7707
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5054
#
# Prediction stats:
# pred_risk - Mean: 0.6982, Min: 0.6938, Max: 0.7718
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5104
#
# Prediction stats:
# pred_risk - Mean: 0.6980, Min: 0.6938, Max: 0.7627
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5689
#
# Prediction stats:
# pred_risk - Mean: 0.6982, Min: 0.6938, Max: 0.7610
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4699
#
# Prediction stats:
# pred_risk - Mean: 0.6982, Min: 0.6938, Max: 0.7670
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5611
#
# Prediction stats:
# pred_risk - Mean: 0.6981, Min: 0.6938, Max: 0.7710
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4798
#
# Prediction stats:
# pred_risk - Mean: 0.6981, Min: 0.6938, Max: 0.7723
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5374
#
# Prediction stats:
# pred_risk - Mean: 0.6981, Min: 0.6938, Max: 0.7525
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5041
#
# Prediction stats:
# pred_risk - Mean: 0.6980, Min: 0.6938, Max: 0.7684
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4497
#
# Prediction stats:
# pred_risk - Mean: 0.6980, Min: 0.6938, Max: 0.7709
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4818
#
# Prediction stats:
# pred_risk - Mean: 0.6980, Min: 0.6938, Max: 0.7653
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4860
#
# Prediction stats:
# pred_risk - Mean: 0.6980, Min: 0.6938, Max: 0.7672
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6449
#
# Prediction stats:
# pred_risk - Mean: 0.6980, Min: 0.6938, Max: 0.7719
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5989
#
# Prediction stats:
# pred_risk - Mean: 0.6979, Min: 0.6938, Max: 0.7680
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5022
#
# Prediction stats:
# pred_risk - Mean: 0.6978, Min: 0.6938, Max: 0.7688
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6006
#
# Prediction stats:
# pred_risk - Mean: 0.6978, Min: 0.6938, Max: 0.7625
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5056
#
# Prediction stats:
# pred_risk - Mean: 0.6978, Min: 0.6938, Max: 0.7664
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4533
#
# Prediction stats:
# pred_risk - Mean: 0.6977, Min: 0.6938, Max: 0.7717
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4924
#
# Prediction stats:
# pred_risk - Mean: 0.6976, Min: 0.6938, Max: 0.7642
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5351
#
# Prediction stats:
# pred_risk - Mean: 0.6976, Min: 0.6938, Max: 0.7526
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4773
#
# Prediction stats:
# pred_risk - Mean: 0.6975, Min: 0.6938, Max: 0.7726
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5181
#
# Prediction stats:
# pred_risk - Mean: 0.6975, Min: 0.6938, Max: 0.7607
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4715
#
# Prediction stats:
# pred_risk - Mean: 0.6975, Min: 0.6938, Max: 0.7706
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5037
#
# Prediction stats:
# pred_risk - Mean: 0.6975, Min: 0.6938, Max: 0.7591
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3193
#
# Prediction stats:
# pred_risk - Mean: 0.6975, Min: 0.6938, Max: 0.7658
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5122
#
# Prediction stats:
# pred_risk - Mean: 0.6974, Min: 0.6938, Max: 0.7651
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.7011
#
# Prediction stats:
# pred_risk - Mean: 0.6976, Min: 0.6939, Max: 0.7586
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5318
#
# Prediction stats:
# pred_risk - Mean: 0.6977, Min: 0.6940, Max: 0.7629
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3743
#
# Prediction stats:
# pred_risk - Mean: 0.6977, Min: 0.6941, Max: 0.7579
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5191
#
# Prediction stats:
# pred_risk - Mean: 0.6978, Min: 0.6941, Max: 0.7756
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5331
#
# Prediction stats:
# pred_risk - Mean: 0.6979, Min: 0.6942, Max: 0.7664
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4851
#
# Prediction stats:
# pred_risk - Mean: 0.6980, Min: 0.6943, Max: 0.7576
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5686
#
# Prediction stats:
# pred_risk - Mean: 0.6982, Min: 0.6945, Max: 0.7731
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5341
#
# Prediction stats:
# pred_risk - Mean: 0.6985, Min: 0.6947, Max: 0.7663
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5065
#
# Prediction stats:
# pred_risk - Mean: 0.6988, Min: 0.6949, Max: 0.7623
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6120
#
# Prediction stats:
# pred_risk - Mean: 0.6992, Min: 0.6952, Max: 0.7662
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.7027
#
# Prediction stats:
# pred_risk - Mean: 0.6998, Min: 0.6956, Max: 0.7711
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5018
#
# Prediction stats:
# pred_risk - Mean: 0.7001, Min: 0.6959, Max: 0.7694
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5205
#
# Prediction stats:
# pred_risk - Mean: 0.7005, Min: 0.6961, Max: 0.7823
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5897
#
# Prediction stats:
# pred_risk - Mean: 0.7008, Min: 0.6961, Max: 0.7747
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5039
#
# Prediction stats:
# pred_risk - Mean: 0.7010, Min: 0.6964, Max: 0.7879
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5208
#
# Prediction stats:
# pred_risk - Mean: 0.7014, Min: 0.6965, Max: 0.7867
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5863
#
# Prediction stats:
# pred_risk - Mean: 0.7019, Min: 0.6967, Max: 0.8023
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5369
#
# Prediction stats:
# pred_risk - Mean: 0.7025, Min: 0.6971, Max: 0.8111
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5165
#
# Prediction stats:
# pred_risk - Mean: 0.7029, Min: 0.6972, Max: 0.7971
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5297
#
# Prediction stats:
# pred_risk - Mean: 0.7033, Min: 0.6976, Max: 0.7993
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5527
#
# Prediction stats:
# pred_risk - Mean: 0.7038, Min: 0.6979, Max: 0.8080
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4539
#
# Prediction stats:
# pred_risk - Mean: 0.7043, Min: 0.6979, Max: 0.8032
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5131
#
# Prediction stats:
# pred_risk - Mean: 0.7046, Min: 0.6983, Max: 0.8153
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5476
#
# Prediction stats:
# pred_risk - Mean: 0.7052, Min: 0.6987, Max: 0.8142
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.2626
#
# Prediction stats:
# pred_risk - Mean: 0.7058, Min: 0.6988, Max: 0.8343
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4765
#
# Prediction stats:
# pred_risk - Mean: 0.7065, Min: 0.6989, Max: 0.8399
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5152
#
# Prediction stats:
# pred_risk - Mean: 0.7072, Min: 0.6994, Max: 0.8502
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6200
#
# Prediction stats:
# pred_risk - Mean: 0.7081, Min: 0.6997, Max: 0.8344
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3398
#
# Prediction stats:
# pred_risk - Mean: 0.7093, Min: 0.7000, Max: 0.8574
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3842
#
# Prediction stats:
# pred_risk - Mean: 0.7102, Min: 0.7003, Max: 0.8815
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5524
#
# Prediction stats:
# pred_risk - Mean: 0.7104, Min: 0.7003, Max: 0.8665
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5229
#
# Prediction stats:
# pred_risk - Mean: 0.7111, Min: 0.7008, Max: 0.8824
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5116
#
# Prediction stats:
# pred_risk - Mean: 0.7121, Min: 0.7011, Max: 0.9070
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4904
#
# Prediction stats:
# pred_risk - Mean: 0.7125, Min: 0.7014, Max: 0.8764
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5513
#
# Prediction stats:
# pred_risk - Mean: 0.7134, Min: 0.7017, Max: 0.8974
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.1789
#
# Prediction stats:
# pred_risk - Mean: 0.7153, Min: 0.7019, Max: 0.9291
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6365
#
# Prediction stats:
# pred_risk - Mean: 0.7168, Min: 0.7019, Max: 0.9390
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4376
#
# Prediction stats:
# pred_risk - Mean: 0.7176, Min: 0.7018, Max: 0.9584
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5023
#
# Prediction stats:
# pred_risk - Mean: 0.7187, Min: 0.7021, Max: 0.9690
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.8881
#
# Prediction stats:
# pred_risk - Mean: 0.7211, Min: 0.7023, Max: 1.0226
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4807
#
# Prediction stats:
# pred_risk - Mean: 0.7237, Min: 0.7027, Max: 1.0175
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5594
#
# Prediction stats:
# pred_risk - Mean: 0.7259, Min: 0.7024, Max: 1.0743
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5738
#
# Prediction stats:
# pred_risk - Mean: 0.7281, Min: 0.7032, Max: 1.0832
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5041
#
# Prediction stats:
# pred_risk - Mean: 0.7311, Min: 0.7034, Max: 1.2623
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5264
#
# Prediction stats:
# pred_risk - Mean: 0.7344, Min: 0.7038, Max: 1.1942
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4003
#
# Prediction stats:
# pred_risk - Mean: 0.7383, Min: 0.7041, Max: 1.3836
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5996
#
# Prediction stats:
# pred_risk - Mean: 0.7408, Min: 0.7042, Max: 1.2446
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.2341
#
# Prediction stats:
# pred_risk - Mean: 0.7399, Min: 0.7044, Max: 1.1852
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4491
#
# Prediction stats:
# pred_risk - Mean: 0.7398, Min: 0.7047, Max: 1.1467
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5321
#
# Prediction stats:
# pred_risk - Mean: 0.7413, Min: 0.7048, Max: 1.2249
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6005
#
# Prediction stats:
# pred_risk - Mean: 0.7441, Min: 0.7053, Max: 1.2994
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5602
#
# Prediction stats:
# pred_risk - Mean: 0.7471, Min: 0.7052, Max: 1.3927
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6222
#
# Prediction stats:
# pred_risk - Mean: 0.7507, Min: 0.7065, Max: 1.3552
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.2567
#
# Prediction stats:
# pred_risk - Mean: 0.7546, Min: 0.7070, Max: 1.4839
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5377
#
# Prediction stats:
# pred_risk - Mean: 0.7581, Min: 0.7080, Max: 1.5115
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.7987
#
# Prediction stats:
# pred_risk - Mean: 0.7570, Min: 0.7082, Max: 1.4157
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5791
#
# Prediction stats:
# pred_risk - Mean: 0.7574, Min: 0.7086, Max: 1.5988
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5365
#
# Prediction stats:
# pred_risk - Mean: 0.7563, Min: 0.7087, Max: 1.4219
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6218
#
# Prediction stats:
# pred_risk - Mean: 0.7580, Min: 0.7088, Max: 1.3810
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4630
#
# Prediction stats:
# pred_risk - Mean: 0.7600, Min: 0.7089, Max: 1.6213
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4909
#
# Prediction stats:
# pred_risk - Mean: 0.7609, Min: 0.7096, Max: 1.6089
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5500
#
# Prediction stats:
# pred_risk - Mean: 0.7594, Min: 0.7088, Max: 1.5241
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5435
#
# Prediction stats:
# pred_risk - Mean: 0.7576, Min: 0.7103, Max: 1.4092
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5428
#
# Prediction stats:
# pred_risk - Mean: 0.7581, Min: 0.7101, Max: 1.5342
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.0708
#
# Prediction stats:
# pred_risk - Mean: 0.7595, Min: 0.7103, Max: 1.5842
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4545
#
# ...
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 1.0019
#
# Prediction stats:
# pred_risk - Mean: 0.7150, Min: 0.7037, Max: 0.9754
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5763
#
# Prediction stats:
# pred_risk - Mean: 0.7140, Min: 0.7033, Max: 0.9466
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.0907
#
# Prediction stats:
# pred_risk - Mean: 0.7136, Min: 0.7030, Max: 0.9563
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5719
#
# Prediction stats:
# pred_risk - Mean: 0.7128, Min: 0.7026, Max: 0.9207
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.7099
#
# Prediction stats:
# pred_risk - Mean: 0.7121, Min: 0.7025, Max: 0.9310
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4940
#
# Prediction stats:
# pred_risk - Mean: 0.7122, Min: 0.7024, Max: 0.9413
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6733
#
# Prediction stats:
# pred_risk - Mean: 0.7115, Min: 0.7021, Max: 0.9166
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5409
#
# Prediction stats:
# pred_risk - Mean: 0.7109, Min: 0.7019, Max: 0.9282
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6282
#
# Prediction stats:
# pred_risk - Mean: 0.7105, Min: 0.7018, Max: 0.8551
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5296
#
# Prediction stats:
# pred_risk - Mean: 0.7103, Min: 0.7016, Max: 0.9148
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3396
#
# Prediction stats:
# pred_risk - Mean: 0.7098, Min: 0.7014, Max: 0.8960
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4908
#
# Prediction stats:
# pred_risk - Mean: 0.7096, Min: 0.7011, Max: 0.8973
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5242
#
# Prediction stats:
# pred_risk - Mean: 0.7093, Min: 0.7012, Max: 0.8625
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4837
#
# Prediction stats:
# pred_risk - Mean: 0.7094, Min: 0.7012, Max: 0.8805
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5285
#
# Prediction stats:
# pred_risk - Mean: 0.7094, Min: 0.7013, Max: 0.8792
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5786
#
# Prediction stats:
# pred_risk - Mean: 0.7094, Min: 0.7014, Max: 0.8513
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4610
#
# Prediction stats:
# pred_risk - Mean: 0.7098, Min: 0.7015, Max: 0.8911
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5479
#
# Prediction stats:
# pred_risk - Mean: 0.7100, Min: 0.7017, Max: 0.8822
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5159
#
# Prediction stats:
# pred_risk - Mean: 0.7105, Min: 0.7019, Max: 0.9032
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4304
#
# Prediction stats:
# pred_risk - Mean: 0.7110, Min: 0.7022, Max: 0.8879
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4879
#
# Prediction stats:
# pred_risk - Mean: 0.7112, Min: 0.7024, Max: 0.8654
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4879
#
# Prediction stats:
# pred_risk - Mean: 0.7114, Min: 0.7023, Max: 0.9050
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5019
#
# Prediction stats:
# pred_risk - Mean: 0.7115, Min: 0.7025, Max: 0.8822
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4689
#
# Prediction stats:
# pred_risk - Mean: 0.7115, Min: 0.7024, Max: 0.9059
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4506
#
# Prediction stats:
# pred_risk - Mean: 0.7115, Min: 0.7026, Max: 0.9104
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3843
#
# Prediction stats:
# pred_risk - Mean: 0.7115, Min: 0.7026, Max: 0.9239
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5370
#
# Prediction stats:
# pred_risk - Mean: 0.7115, Min: 0.7027, Max: 0.9205
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4020
#
# Prediction stats:
# pred_risk - Mean: 0.7111, Min: 0.7026, Max: 0.8835
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5086
#
# Prediction stats:
# pred_risk - Mean: 0.7113, Min: 0.7026, Max: 0.9202
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5288
#
# Prediction stats:
# pred_risk - Mean: 0.7113, Min: 0.7026, Max: 0.8898
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6726
#
# Prediction stats:
# pred_risk - Mean: 0.7110, Min: 0.7025, Max: 0.9269
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.0291
#
# Prediction stats:
# pred_risk - Mean: 0.7105, Min: 0.7023, Max: 0.8569
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5988
#
# Prediction stats:
# pred_risk - Mean: 0.7103, Min: 0.7024, Max: 0.8456
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4522
#
# Prediction stats:
# pred_risk - Mean: 0.7102, Min: 0.7024, Max: 0.8618
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.2695
#
# Prediction stats:
# pred_risk - Mean: 0.7102, Min: 0.7024, Max: 0.8759
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5744
#
# Prediction stats:
# pred_risk - Mean: 0.7102, Min: 0.7024, Max: 0.8780
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5304
#
# Prediction stats:
# pred_risk - Mean: 0.7099, Min: 0.7024, Max: 0.8501
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6832
#
# Prediction stats:
# pred_risk - Mean: 0.7099, Min: 0.7023, Max: 0.8460
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4878
#
# Prediction stats:
# pred_risk - Mean: 0.7098, Min: 0.7025, Max: 0.8502
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6836
#
# Prediction stats:
# pred_risk - Mean: 0.7098, Min: 0.7023, Max: 0.8699
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5187
#
# Prediction stats:
# pred_risk - Mean: 0.7102, Min: 0.7024, Max: 0.8610
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4438
#
# Prediction stats:
# pred_risk - Mean: 0.7102, Min: 0.7025, Max: 0.9056
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5121
#
# Prediction stats:
# pred_risk - Mean: 0.7102, Min: 0.7025, Max: 0.8665
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5185
#
# Prediction stats:
# pred_risk - Mean: 0.7104, Min: 0.7026, Max: 0.8567
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6723
#
# Prediction stats:
# pred_risk - Mean: 0.7102, Min: 0.7027, Max: 0.8515
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5247
#
# Prediction stats:
# pred_risk - Mean: 0.7105, Min: 0.7028, Max: 0.8851
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5648
#
# Prediction stats:
# pred_risk - Mean: 0.7104, Min: 0.7026, Max: 0.8432
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5043
#
# Prediction stats:
# pred_risk - Mean: 0.7104, Min: 0.7025, Max: 0.8996
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5166
#
# Prediction stats:
# pred_risk - Mean: 0.7104, Min: 0.7026, Max: 0.8402
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.2316
#
# Prediction stats:
# pred_risk - Mean: 0.7103, Min: 0.7025, Max: 0.8658
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3945
#
# Prediction stats:
# pred_risk - Mean: 0.7102, Min: 0.7026, Max: 0.8778
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4614
#
# Prediction stats:
# pred_risk - Mean: 0.7102, Min: 0.7026, Max: 0.8808
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6822
#
# Prediction stats:
# pred_risk - Mean: 0.7102, Min: 0.7025, Max: 0.8625
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4258
#
# Prediction stats:
# pred_risk - Mean: 0.7096, Min: 0.7023, Max: 0.8543
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.7655
#
# Prediction stats:
# pred_risk - Mean: 0.7095, Min: 0.7022, Max: 0.8708
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4662
#
# Prediction stats:
# pred_risk - Mean: 0.7091, Min: 0.7020, Max: 0.8519
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.0402
#
# Prediction stats:
# pred_risk - Mean: 0.7089, Min: 0.7019, Max: 0.8610
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3757
#
# Prediction stats:
# pred_risk - Mean: 0.7087, Min: 0.7018, Max: 0.8406
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5195
#
# Prediction stats:
# pred_risk - Mean: 0.7087, Min: 0.7017, Max: 0.8733
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4570
#
# Prediction stats:
# pred_risk - Mean: 0.7085, Min: 0.7017, Max: 0.8445
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4445
#
# Prediction stats:
# pred_risk - Mean: 0.7082, Min: 0.7015, Max: 0.8626
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5423
#
# Prediction stats:
# pred_risk - Mean: 0.7082, Min: 0.7014, Max: 0.8561
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5187
#
# Prediction stats:
# pred_risk - Mean: 0.7078, Min: 0.7013, Max: 0.8276
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5109
#
# Prediction stats:
# pred_risk - Mean: 0.7079, Min: 0.7013, Max: 0.8599
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5430
#
# Prediction stats:
# pred_risk - Mean: 0.7078, Min: 0.7011, Max: 0.8447
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4982
#
# Prediction stats:
# pred_risk - Mean: 0.7075, Min: 0.7010, Max: 0.8378
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3858
#
# Prediction stats:
# pred_risk - Mean: 0.7075, Min: 0.7009, Max: 0.8526
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6021
#
# Prediction stats:
# pred_risk - Mean: 0.7073, Min: 0.7008, Max: 0.8460
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5399
#
# Prediction stats:
# pred_risk - Mean: 0.7070, Min: 0.7005, Max: 0.8429
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5321
#
# Prediction stats:
# pred_risk - Mean: 0.7068, Min: 0.7006, Max: 0.8289
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.1093
#
# Prediction stats:
# pred_risk - Mean: 0.7065, Min: 0.7004, Max: 0.8266
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5204
#
# Prediction stats:
# pred_risk - Mean: 0.7061, Min: 0.7003, Max: 0.8428
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5099
#
# Prediction stats:
# pred_risk - Mean: 0.7059, Min: 0.7001, Max: 0.8243
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5002
#
# Prediction stats:
# pred_risk - Mean: 0.7059, Min: 0.7001, Max: 0.8214
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5247
#
# Prediction stats:
# pred_risk - Mean: 0.7060, Min: 0.7001, Max: 0.8468
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3469
#
# Prediction stats:
# pred_risk - Mean: 0.7059, Min: 0.7001, Max: 0.8329
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5349
#
# Prediction stats:
# pred_risk - Mean: 0.7060, Min: 0.7002, Max: 0.8288
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4816
#
# Prediction stats:
# pred_risk - Mean: 0.7060, Min: 0.7001, Max: 0.8348
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5126
#
# Prediction stats:
# pred_risk - Mean: 0.7058, Min: 0.7001, Max: 0.8358
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5228
#
# Prediction stats:
# pred_risk - Mean: 0.7059, Min: 0.7000, Max: 0.8337
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5135
#
# Prediction stats:
# pred_risk - Mean: 0.7058, Min: 0.7000, Max: 0.8291
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4910
#
# Prediction stats:
# pred_risk - Mean: 0.7055, Min: 0.6999, Max: 0.8326
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4741
#
# Prediction stats:
# pred_risk - Mean: 0.7055, Min: 0.6999, Max: 0.8204
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4297
#
# Prediction stats:
# pred_risk - Mean: 0.7054, Min: 0.6998, Max: 0.8267
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5053
#
# Prediction stats:
# pred_risk - Mean: 0.7052, Min: 0.6998, Max: 0.8102
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.9132
#
# Prediction stats:
# pred_risk - Mean: 0.7050, Min: 0.6997, Max: 0.8116
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4646
#
# Prediction stats:
# pred_risk - Mean: 0.7047, Min: 0.6995, Max: 0.8022
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.6464
#
# Prediction stats:
# pred_risk - Mean: 0.7046, Min: 0.6995, Max: 0.8082
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4968
#
# Prediction stats:
# pred_risk - Mean: 0.7044, Min: 0.6994, Max: 0.8200
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4991
#
# Prediction stats:
# pred_risk - Mean: 0.7042, Min: 0.6992, Max: 0.8204
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5254
#
# Prediction stats:
# pred_risk - Mean: 0.7038, Min: 0.6989, Max: 0.8104
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4831
#
# Prediction stats:
# pred_risk - Mean: 0.7031, Min: 0.6987, Max: 0.7864
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4768
#
# Prediction stats:
# pred_risk - Mean: 0.7028, Min: 0.6986, Max: 0.7924
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.3456
#
# Prediction stats:
# pred_risk - Mean: 0.7026, Min: 0.6984, Max: 0.7870
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4834
#
# Prediction stats:
# pred_risk - Mean: 0.7021, Min: 0.6983, Max: 0.7818
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5308
#
# Prediction stats:
# pred_risk - Mean: 0.7019, Min: 0.6983, Max: 0.7731
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4685
#
# Prediction stats:
# pred_risk - Mean: 0.7019, Min: 0.6982, Max: 0.7826
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4306
#
# Prediction stats:
# pred_risk - Mean: 0.7018, Min: 0.6982, Max: 0.7755
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.4864
#
# Prediction stats:
# pred_risk - Mean: 0.7018, Min: 0.6982, Max: 0.7711
# true_risk - Mean: 4.4439, Min: 0.0010, Max: 66.5194
# Gradient norm before clipping: 0.5068
# Epoch 5
# Train Loss: 1591.9081
# Test Regret: 0.2124
# Best Regret: 0.2124

# %%
logs
# Out:
# ([1578.7485361328124,
#   1587.533451171875,
#   1568.4813037109375,
#   1592.361716796875,
#   1591.9081044921875],
#  [tensor([0.2222], device='cuda:0'),
#   tensor([0.2359], device='cuda:0'),
#   tensor([0.2132], device='cuda:0'),
#   tensor([0.2136], device='cuda:0'),
#   tensor([0.2124], device='cuda:0')])
